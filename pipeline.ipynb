# %% [markdown]
# ### Download dataset

# %%
# Download PTB-XL
python c:\Users\amarconi\Desktop\kepler-ecg\scripts\download_dataset.py https://physionet.org/files/ptb-xl/1.0.3/

# Download Chapman-Shaoxing
python c:\Users\amarconi\Desktop\kepler-ecg\scripts\download_dataset.py https://physionet.org/files/ptb-xl/1.0.3/

# Download CPSC 2018
python c:\Users\amarconi\Desktop\kepler-ecg\scripts\download_dataset.py http://2018.icbeb.org/Challenge.html

# Download PTB-XL
python c:\Users\amarconi\Desktop\kepler-ecg\scripts\download_dataset.py https://physionet.org/files/ptb-xl/1.0.3/
# Out:
# ^C
